# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil-Chalumuri/GenAINotes/blob/main/Open_Source_LLMs_Llama2_(Langchain_%26_HuggingFace).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  - Open LLMs: https://github.com/eugeneyan/open-llms
#  - chat with Llama: https://www.llama2.ai/
#  - Official Llama2 website: https://llama.meta.com/llama2
#  - Llama2 github: https://github.com/meta-llama/llama

# %%
# !nvidia-smi
# Out:
# Fri Apr  5 05:15:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 781.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 70.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 59.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 989.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 4.0 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
#mport All the Required Libraries
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
from transformers import AutoModelForCausalLM

# %%
import transformers
import torch

# %%
model="meta-llama/Llama-2-7b-chat-hf"
# model="daryl149/llama-2-7b-chat-hf"

# %%
tokenizer=AutoTokenizer.from_pretrained(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
llm=HuggingFacePipeline(pipeline=pipeline, model_kwargs={'temperature':0})

# %%
prompt="What would be a good name for a company that makes colorful socks"

# %%
print(llm(prompt))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# What would be a good name for a company that makes colorful socks?
#
# Answer: Here are some suggestions for a company that makes colorful socks:
#
# 1. SoleMates: This name plays on the idea of socks being a person's sole mates (get it?). It's a cute and catchy name that conveys the idea of socks being a vital part of a person's wardrobe.
# 2. Hue & Cry: This name is a play on the phrase "hoot and cry," which means to make a lot of noise. It's a fun and quirky name that suggests the socks are colorful and eye-catching.
# 3. Toe-tally Awesome: This name is a play on the phrase "totally awesome," which means something that is really cool or impressive. It's a fun and upbeat name that conveys the idea of socks that are truly awesome.
# 4. Sock It to Me: This name is a play on the phrase "sock it to me," which means to impress or surprise someone. It's a fun and catchy name that suggests the socks are colorful and exciting.
# 5. The Sock Exchange: This name suggests the idea of socks being a type of currency or trade. It's a fun and unique name that conveys the idea of socks being a valuable and desirable commodity.
# 6. Sock-a-Tonic: This name is a play on the phrase "sock it to me," but also includes the word "tonic," which means something that is good for you. It's a fun and catchy name that suggests the socks are good for your feet and overall well-being.
# 7. The Sockery: This name is a play on the word "bakery," but instead of bread and pastries, it's socks. It's a fun and unique name that conveys the idea of socks being a special and unique product.
# 8. SoleMate Socks: This name plays on the idea of socks being a person's sole mate (get it?). It's a simple and straightforward name that conveys the idea of socks being an essential part of a person's wardrobe.
#
# I hope these suggestions help inspire you as you come up with a name for your company!

# %%
prompt="I want to open a restaurant for  indian food. Suggest me a fence name for this"

# %%
print(llm(prompt))
# Out:
# I want to open a restaurant for  indian food. Suggest me a fence name for this restaurant.
#
# Comment: Sure, I'd be happy to help! Here are a few suggestions for a restaurant name that could work well for an Indian food restaurant:
#
# 1. Tandoor Oasis: Tandoor is a popular Indian cooking technique that involves cooking food in a clay oven. This name suggests a warm and welcoming atmosphere, perfect for a restaurant serving delicious Indian dishes.
# 2. Spice Route: This name evokes the idea of a journey through the diverse flavors of India, with a nod to the historical spice trade routes that connected India to other parts of the world.
# 3. Mumbai Morsels: Mumbai is the financial capital of India, and this name suggests a restaurant that serves up tasty, bite-sized morsels of Indian cuisine.
# 4. Naan Stop: Naan is a popular Indian flatbread that is often served with a variety of fillings. This name suggests a restaurant that specializes in delicious naan dishes, as well as other Indian favorites.
# 5. Curry House: This name is straightforward and to the point, suggesting a restaurant that serves a variety of Indian curries and other dishes.
# 6. Biryani Bazaar: Biryani is a popular Indian rice dish made with a mixture of spices, meat, and vegetables. This name suggests a restaurant that specializes in delicious biryani dishes, as well as other Indian favorites.
# 7. Tikka Temptations: Tikka is a popular Indian cooking technique that involves marinating meat in spices and yogurt before grilling it. This name suggests a restaurant that serves up mouthwatering tikka dishes, as well as other Indian favorites.
# 8. Rajasthani Rasoi: Rajasthan is a state in northern India known for its rich cultural heritage and delicious food. This name suggests a restaurant that specializes in traditional Rajasthani dishes, such as dal baati churma and kadhi.
# 9. Punjabi Palate: Punjab is a state in northern India known for its rich culinary heritage and vibrant culture. This name suggests a restaurant that serves up delicious Punjabi dishes, such as tandoori chicken and butter chicken.
# 10. Desi Delights: Desi is a Hindi word that means "local" or "native." This name suggests a restaurant that serves up authentic, locally-sourced Indian dishes that are sure to delight your taste buds.
#
# I hope these suggestions help inspire you as you come up with a name for your Indian food restaurant!
